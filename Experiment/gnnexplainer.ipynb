# %%
import pandas as pd
import numpy as np

X_train = pd.read_csv('./datasets/TON-IoT/ton_iot_train.csv')
X_test = pd.read_csv('./datasets/TON-IoT/ton_iot_test.csv')
X = pd.concat([X_train, X_test])
X.sort_values(by='ID', ascending=True, inplace=True)

# %%
X
# Out:
#             ID                src_ip               dst_ip     proto   service  \
# 274326       0   172.27.226.140:1883  192.168.1.152:52976  0.798147  0.260632
# 179598       1   172.24.99.246:47260  192.168.1.255:15600 -1.252024  0.260632
# 67026        2    172.18.57.119:1880  192.168.1.152:51782  0.798147  0.260632
# 101166       3   172.18.164.17:34296  192.168.1.152:10502  0.798147  0.260632
# 4404         4    172.29.91.92:46608     192.168.1.190:53 -1.252024 -1.502312
# ...        ...                   ...                  ...       ...       ...
# 123902  461038   172.20.31.166:33108     176.28.50.165:80  0.798147  0.260632
# 70894   461039  172.20.166.189:37242    34.230.157.88:443  0.798147  0.260632
# 225765  461040   172.29.243.207:4444  192.168.1.193:49178  0.798147  0.260632
# 305332  461041   172.30.171.98:60816    104.98.29.100:443  0.798147  0.260632
# 154449  461042   172.24.250.26:41054    151.101.24.64:443  0.798147  0.260632
#
#           duration  src_bytes  dst_bytes  conn_state  missed_bytes  ...  \
# 274326  160.494251   0.125981   3.392807   -0.679894     -0.004621  ...
# 179598   -0.017933  -0.011044  -0.010582   -0.341502     -0.004621  ...
# 67026    -0.017933  -0.011044  -0.010582   -0.679894     -0.004621  ...
# 101166   -0.017933  -0.011044  -0.010582   -0.679894     -0.004621  ...
# 4404     -0.017932  -0.011044  -0.010558   -1.231669     -0.004621  ...
# ...            ...        ...        ...         ...           ...  ...
# 123902   -0.017933  -0.011044  -0.010582   -0.341502     -0.004621  ...
# 70894    -0.017933  -0.011044  -0.010582   -0.679894     -0.004621  ...
# 225765    0.560694  -0.003149  -0.010371   -0.679894     -0.004621  ...
# 305332    0.028280  -0.011042  -0.010579   -0.028912     -0.004621  ...
# 154449    0.027645  -0.011042  -0.010579   -0.028912     -0.004621  ...
#
#         http_trans_depth  http_method  http_version  http_request_body_len  \
# 274326          0.022966     0.021033      0.022685               -0.00539
# 179598          0.022966     0.021033      0.022685               -0.00539
# 67026           0.022966     0.021033      0.022685               -0.00539
# 101166          0.022966     0.021033      0.022685               -0.00539
# 4404            0.022966     0.021033      0.022685               -0.00539
# ...                  ...          ...           ...                    ...
# 123902          0.022966     0.021033      0.022685               -0.00539
# 70894           0.022966     0.021033      0.022685               -0.00539
# 225765          0.022966     0.021033      0.022685               -0.00539
# 305332          0.022966     0.021033      0.022685               -0.00539
# 154449          0.022966     0.021033      0.022685               -0.00539
#
#         http_response_body_len  http_status_code  http_orig_mime_types  \
# 274326               -0.003103          0.018893              0.006307
# 179598               -0.003103          0.018893              0.006307
# 67026                -0.003103          0.018893              0.006307
# 101166               -0.003103          0.018893              0.006307
# 4404                 -0.003103          0.018893              0.006307
# ...                        ...               ...                   ...
# 123902               -0.003103          0.018893              0.006307
# 70894                -0.003103          0.018893              0.006307
# 225765               -0.003103          0.018893              0.006307
# 305332               -0.003103          0.018893              0.006307
# 154449               -0.003103          0.018893              0.006307
#
#         http_resp_mime_types  label  type
# 274326               0.00171      0     0
# 179598               0.00171      0     0
# 67026                0.00171      0     0
# 101166               0.00171      0     0
# 4404                 0.00171      0     0
# ...                      ...    ...   ...
# 123902               0.00171      1     8
# 70894                0.00171      1     6
# 225765               0.00171      1     1
# 305332               0.00171      1     9
# 154449               0.00171      1     9
#
# [461043 rows x 35 columns]

# %%
explain_id = 461038

# %%
# 找到id对应两跳的数据
expand_round = 2
ids = np.array([explain_id])
for _ in range(expand_round):
    cur_nodes = np.unique(np.concatenate([X[X['ID'].isin(ids)]['src_ip'].values, X[X['ID'].isin(ids)]['dst_ip'].values]))
    not_in_ids = X[~X['ID'].isin(ids)]
    not_in_ids = not_in_ids[(not_in_ids['src_ip'].isin(cur_nodes)) | (not_in_ids['dst_ip'].isin(cur_nodes))]
    if not_in_ids.shape[0] == 0:
        break
    ids = np.concatenate([ids, not_in_ids['ID'].values])

# %%
ids
# Out:
# array([461038, 186511, 186569, ..., 378328, 378329, 378330], dtype=int64)

# %%
sub_X = X[X['ID'].isin(ids)].copy()

# %%
sub_X
# Out:
#             ID               src_ip            dst_ip     proto   service  \
# 34361   186511    172.23.146.113:80  176.28.50.165:80  0.798147  0.260632
# 87481   186569    172.16.169.193:80  176.28.50.165:80  0.798147  0.260632
# 1195    186570     172.20.38.120:80  176.28.50.165:80  0.798147  0.260632
# 227288  186571    172.16.201.125:80  176.28.50.165:80  0.798147  0.260632
# 254359  186572    172.22.247.227:80  176.28.50.165:80  0.798147  0.260632
# ...        ...                  ...               ...       ...       ...
# 166093  378327  172.20.229.80:48288  176.28.50.165:80  0.798147  1.579251
# 310456  378328   172.22.0.240:48292  176.28.50.165:80  0.798147  1.579251
# 12666   378329  172.27.68.167:48294  176.28.50.165:80  0.798147  1.579251
# 128854  378330   172.27.35.83:48304  176.28.50.165:80  0.798147  1.579251
# 123902  461038  172.20.31.166:33108  176.28.50.165:80  0.798147  0.260632
#
#         duration  src_bytes  dst_bytes  conn_state  missed_bytes  ...  \
# 34361  -0.017289  -0.011044  -0.010582    1.368701     -0.004621  ...
# 87481  -0.017933  -0.011044  -0.010582    1.368701     -0.004621  ...
# 1195   -0.017933  -0.011044  -0.010582    1.368701     -0.004621  ...
# 227288 -0.017933  -0.011044  -0.010582    1.368701     -0.004621  ...
# 254359 -0.017933  -0.011044  -0.010582    1.368701     -0.004621  ...
# ...          ...        ...        ...         ...           ...  ...
# 166093  0.113009  -0.010890  -0.010556    2.716324     -0.004621  ...
# 310456  0.113121  -0.010739  -0.010556    2.716324     -0.004621  ...
# 12666   0.113096  -0.010857  -0.010556    2.716324     -0.004621  ...
# 128854  0.113132  -0.010797  -0.010556    2.716324     -0.004621  ...
# 123902 -0.017933  -0.011044  -0.010582   -0.341502     -0.004621  ...
#
#         http_trans_depth  http_method  http_version  http_request_body_len  \
# 34361           0.022966     0.021033      0.022685               -0.00539
# 87481           0.022966     0.021033      0.022685               -0.00539
# 1195            0.022966     0.021033      0.022685               -0.00539
# 227288          0.022966     0.021033      0.022685               -0.00539
# 254359          0.022966     0.021033      0.022685               -0.00539
# ...                  ...          ...           ...                    ...
# 166093          0.022966     0.021033      0.022685               -0.00539
# 310456          0.022966     0.021033      0.022685               -0.00539
# 12666           0.022966     0.021033      0.022685               -0.00539
# 128854          0.022966     0.021033      0.022685               -0.00539
# 123902          0.022966     0.021033      0.022685               -0.00539
#
#         http_response_body_len  http_status_code  http_orig_mime_types  \
# 34361                -0.003103          0.018893              0.006307
# 87481                -0.003103          0.018893              0.006307
# 1195                 -0.003103          0.018893              0.006307
# 227288               -0.003103          0.018893              0.006307
# 254359               -0.003103          0.018893              0.006307
# ...                        ...               ...                   ...
# 166093               -0.003103          0.018893              0.006307
# 310456               -0.003103          0.018893              0.006307
# 12666                -0.003103          0.018893              0.006307
# 128854               -0.003103          0.018893              0.006307
# 123902               -0.003103          0.018893              0.006307
#
#         http_resp_mime_types  label  type
# 34361                0.00171      1     3
# 87481                0.00171      1     3
# 1195                 0.00171      1     3
# 227288               0.00171      1     3
# 254359               0.00171      1     3
# ...                      ...    ...   ...
# 166093               0.00171      1     8
# 310456               0.00171      1     8
# 12666                0.00171      1     8
# 128854               0.00171      1     8
# 123902               0.00171      1     8
#
# [7524 rows x 35 columns]

# %%
norm_cols = X.columns.to_list()[3:-2]
# X['h'] = X[norm_cols].values.tolist()
sub_X['h'] = sub_X[norm_cols].values.tolist()

# %%
norm_cols
# Out:
# ['proto',
#  'service',
#  'duration',
#  'src_bytes',
#  'dst_bytes',
#  'conn_state',
#  'missed_bytes',
#  'src_pkts',
#  'src_ip_bytes',
#  'dst_pkts',
#  'dst_ip_bytes',
#  'dns_qclass',
#  'dns_qtype',
#  'dns_rcode',
#  'dns_AA',
#  'dns_RD',
#  'dns_RA',
#  'dns_rejected',
#  'ssl_version',
#  'ssl_cipher',
#  'ssl_resumed',
#  'ssl_established',
#  'http_trans_depth',
#  'http_method',
#  'http_version',
#  'http_request_body_len',
#  'http_response_body_len',
#  'http_status_code',
#  'http_orig_mime_types',
#  'http_resp_mime_types']

# %%
from models.GraphSAGE import SAGE
from models.MLP import MLPPredictor
import torch.nn.functional as F
import torch.nn as nn
import networkx as nx
from dgl import from_networkx
import torch as th

class Model(nn.Module):
    def __init__(self, ndim_in, ndim_out, edim, activation, dropout, bin=False):
        super(Model, self).__init__()
        self.gnn = SAGE(ndim_in, ndim_out, edim, activation, dropout)
        if bin:
            self.pred = MLPPredictor(ndim_out, edim, 2)
        else:
            self.pred = MLPPredictor(ndim_out, edim, 10)
    def forward(self, g, nfeats, efeats):
        h = self.gnn(g, nfeats, efeats)
        return self.pred(g, h)
    
device = th.device('cuda' if th.cuda.is_available() else 'cpu')
print('Using device:', device)

params={
    'ndim_out': 128,
    'dropout': 0.2,
    'epochs': 500, # 2000
}
bin = False

# 加载模型
print('Loading model...')
model = Model(30, params['ndim_out'], 30, F.relu, params['dropout'], bin)
model.load_state_dict(th.load('pts/TON-IoT-p-ndim_out_128dropout_0.2epochs_500_multi(0.8653).pt'))


model = model.to(device)
model.eval()
# Out:
# Using device: cuda
# Loading model...
# Model(
#   (gnn): SAGE(
#     (layers): ModuleList(
#       (0): SAGELayer(
#         (W_msg): Linear(in_features=60, out_features=128, bias=True)
#         (W_apply): Linear(in_features=158, out_features=128, bias=True)
#       )
#       (1): SAGELayer(
#         (W_msg): Linear(in_features=158, out_features=128, bias=True)
#         (W_apply): Linear(in_features=256, out_features=128, bias=True)
#       )
#     )
#     (dropout): Dropout(p=0.2, inplace=False)
#   )
#   (pred): MLPPredictor(
#     (W): Linear(in_features=286, out_features=10, bias=True)
#     (softmax): Softmax(dim=1)
#   )
# )

# %%
coeffs = {
        "feat_pred": 3.0,
        "feat_size": 1.0,
        "feat_ent": 0.1,
        "edge_pred": 3.0,
        "edge_size": 1.0,
        "edge_ent": 0.1,
    }

def feature_mask_loss(g, pred_feature_masked, feature_mask, eid):
    # feature_mask 是sigmod过的

    eid_selector = g.edata['ID'] == eid
    # MI loss
    type = g.edata['type'][eid_selector][0].item()
    pred_loss = -th.log(pred_feature_masked[eid_selector][:,type].mean())
    pred_loss = coeffs['feat_pred'] * pred_loss

    # size
    feature_mask_size_loss = coeffs['feat_size'] * th.mean(feature_mask)

    # entropy
    feature_mask_ent = -feature_mask * th.log(feature_mask) - (1 - feature_mask) * th.log(1 - feature_mask)
    feature_mask_ent_loss = coeffs['feat_ent'] * th.mean(feature_mask_ent)

    loss = pred_loss + feature_mask_size_loss + feature_mask_ent_loss

    return loss

def edge_mask_loss(g, pred_edge_masked, edge_mask, eid):
    # edge_mask 是sigmod过的

    eid_selector = g.edata['ID'] == eid
    # MI loss
    type = g.edata['type'][eid_selector][0].item()
    pred_loss = -th.log(pred_edge_masked[eid_selector][:,type].mean())
    pred_loss = coeffs['edge_pred'] * pred_loss

    # size
    edge_mask_size_loss = coeffs['edge_size'] * th.mean(edge_mask)

    # entropy
    edge_mask_ent = -edge_mask * th.log(edge_mask) - (1 - edge_mask) * th.log(1 - edge_mask)
    edge_mask_ent_loss = coeffs['edge_ent'] * th.mean(edge_mask_ent)

    loss = pred_loss + edge_mask_size_loss + edge_mask_ent_loss

    return loss

# %%
eattrs = ['ID', 'h', 'label', 'type']
G = nx.from_pandas_edgelist(sub_X, 'src_ip', 'dst_ip', eattrs, create_using=nx.MultiGraph)
G = G.to_directed()
G = from_networkx(G, edge_attrs=eattrs)
G.ndata['h'] = th.ones(G.num_nodes(), G.edata['h'].shape[1])

# feature_mask = nn.Parameter((th.ones(G.edata['h'].shape[1]) * 0.5).unsqueeze(0), requires_grad=True)
# edge_mask = nn.Parameter((th.ones(G.edata['h'].shape[0]) * 0.5).unsqueeze(1), requires_grad=True)

feature_mask = nn.Parameter(th.zeros(G.edata['h'].shape[1]).unsqueeze(0).to(device), requires_grad=True)
edge_mask = nn.Parameter(th.zeros(G.edata['h'].shape[0]).unsqueeze(1).to(device), requires_grad=True)
G = G.to(device)

eid = explain_id

# 训练优化 feature mask
print("Training Feature Mask...")
optimizer = th.optim.Adam([feature_mask], lr=0.01)
Epochs_feat = 1000
for epoch in range(Epochs_feat):
    optimizer.zero_grad()
    pred_feature_masked = model(G, G.ndata['h'], G.edata['h'] * feature_mask.sigmoid())
    loss = feature_mask_loss(G, pred_feature_masked, feature_mask.sigmoid(), eid)
    loss.backward()
    optimizer.step()
    if epoch % 100 == 0:
        print(loss.item())

# 训练优化 edge mask
print("Training Edge Mask...")
optimizer = th.optim.Adam([edge_mask], lr=0.01)
Epochs_edge = 1000
for epoch in range(Epochs_edge):
    optimizer.zero_grad()
    pred_edge_masked = model(G, G.ndata['h'], G.edata['h'] * edge_mask.sigmoid())
    loss = edge_mask_loss(G, pred_edge_masked, edge_mask.sigmoid(), eid)
    loss.backward()
    optimizer.step()
    if epoch % 100 == 0:
        print(loss.item())
# Out:
# Training Feature Mask...
# 8.62088394165039
# -1.8774688243865967
# -3.097667932510376
# -3.7088112831115723
# -4.048563480377197
# -4.282655239105225
# -4.459225654602051
# -4.617644309997559
# -4.751430511474609
# -4.871150970458984
# Training Edge Mask...
# 8.62088394165039
# -1.2937366962432861
# -2.777599334716797
# -3.532231569290161
# -3.9631264209747314
# -4.220959186553955
# -4.398290634155273
# -4.517617702484131
# -4.6150689125061035
# -4.694777965545654

# %%
pred_origin = model(G, G.ndata['h'], G.edata['h'])
pred_feature_masked = model(G, G.ndata['h'], G.edata['h'] * feature_mask.sigmoid())
pred_edge_masked = model(G, G.ndata['h'], G.edata['h'] * edge_mask.sigmoid())

result_df = pd.DataFrame(columns=['ID', 'type'])

result_df['ID'] = th.tensor(G.edata['ID']).cpu().detach().numpy()
result_df['type'] = th.tensor(G.edata['type']).cpu().detach().numpy()
result_df['pred_origin'] = pred_origin.argmax(dim=1).cpu().detach().numpy()
result_df['pred_feature_masked'] = pred_feature_masked.argmax(dim=1).cpu().detach().numpy()
result_df['pred_edge_masked'] = pred_edge_masked.argmax(dim=1).cpu().detach().numpy()
result_df['pred_origin_vec'] = pred_origin.cpu().detach().numpy().tolist()
result_df['pred_feature_masked_vec'] = pred_feature_masked.cpu().detach().numpy().tolist()
result_df['pred_edge_masked_vec'] = pred_edge_masked.cpu().detach().numpy().tolist()
# Out:
# C:\Users\QishuoBai\AppData\Local\Temp\ipykernel_11024\4263885434.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   result_df['ID'] = th.tensor(G.edata['ID']).cpu().detach().numpy()
# C:\Users\QishuoBai\AppData\Local\Temp\ipykernel_11024\4263885434.py:8: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   result_df['type'] = th.tensor(G.edata['type']).cpu().detach().numpy()

# %%
feature_mask.sigmoid().cpu().detach().numpy().squeeze()
# Out:
# array([0.74759525, 0.6981898 , 0.781502  , 0.03672858, 0.01000787,
#        0.8463086 , 0.01753187, 0.07080044, 0.07350193, 0.20582119,
#        0.3138639 , 0.48621708, 0.18198115, 0.2494081 , 0.33669156,
#        0.11877614, 0.48662227, 0.87806207, 0.04725722, 0.01268842,
#        0.01583842, 0.01933276, 0.01359011, 0.03226744, 0.01108051,
#        0.02639668, 0.01147179, 0.08486546, 0.08209796, 0.01742352],
#       dtype=float32)

# %%
edge_mask.sigmoid().cpu().detach().numpy().squeeze()
# Out:
# array([0.90176195, 0.7871096 , 0.7341153 , ..., 0.8647947 , 0.8646968 ,
#        0.13826907], dtype=float32)

# %%
result_df
# Out:
#            ID  type  pred_origin  pred_feature_masked  pred_edge_masked  \
# 0      186511     3            8                    4                 8
# 1      186511     3            8                    8                 8
# 2      186569     3            8                    8                 8
# 3      186570     3            8                    8                 8
# 4      186571     3            8                    8                 8
# ...       ...   ...          ...                  ...               ...
# 15043  378327     8            8                    8                 8
# 15044  378328     8            8                    8                 8
# 15045  378329     8            8                    8                 8
# 15046  378330     8            8                    8                 8
# 15047  461038     8            8                    8                 8
#
#                                          pred_origin_vec  \
# 0      [1.6831613779067993, -14.637893676757812, 4.70...
# 1      [1.6137841939926147, -14.748703956604004, 4.41...
# 2      [1.6708738803863525, -14.682819366455078, 4.28...
# 3      [1.6708741188049316, -14.682818412780762, 4.28...
# 4      [1.6708741188049316, -14.682819366455078, 4.28...
# ...                                                  ...
# 15043  [0.4562591314315796, -15.539422988891602, 4.26...
# 15044  [0.4549154043197632, -15.53243350982666, 4.263...
# 15045  [0.45599043369293213, -15.53803825378418, 4.26...
# 15046  [0.45543110370635986, -15.534314155578613, 4.2...
# 15047  [3.1410818099975586, -15.47372817993164, 4.214...
#
#                                  pred_feature_masked_vec  \
# 0      [1.0798792839050293, -11.42552661895752, 3.830...
# 1      [1.0304782390594482, -11.538680076599121, 3.50...
# 2      [1.0370854139328003, -11.494348526000977, 3.49...
# 3      [1.0370854139328003, -11.494348526000977, 3.49...
# 4      [1.0370854139328003, -11.494348526000977, 3.49...
# ...                                                  ...
# 15043  [0.22852171957492828, -12.073416709899902, 3.4...
# 15044  [0.2275003343820572, -12.072911262512207, 3.42...
# 15045  [0.22835339605808258, -12.07311725616455, 3.42...
# 15046  [0.2278076559305191, -12.073018074035645, 3.42...
# 15047  [2.1395576000213623, -12.145899772644043, 3.34...
#
#                                     pred_edge_masked_vec
# 0      [1.46220064163208, -10.319585800170898, 3.5819...
# 1      [1.2611957788467407, -10.543128967285156, 3.20...
# 2      [1.3240591287612915, -10.51234245300293, 3.053...
# 3      [1.3240593671798706, -10.51234245300293, 3.053...
# 4      [1.3240593671798706, -10.51234245300293, 3.053...
# ...                                                  ...
# 15043  [0.3570142984390259, -11.153517723083496, 3.23...
# 15044  [0.35542821884155273, -11.148160934448242, 3.2...
# 15045  [0.3567150831222534, -11.152436256408691, 3.23...
# 15046  [0.3560119867324829, -11.149601936340332, 3.24...
# 15047  [2.7339673042297363, -11.098540306091309, 3.08...
#
# [15048 rows x 8 columns]

# %%
explainer_result = {}
explainer_result['feature_importance'] = feature_mask.sigmoid().cpu().detach().numpy().squeeze().tolist()
explainer_result['edge_importance'] = []
edge_mask_list = edge_mask.sigmoid().cpu().detach().numpy().squeeze().tolist()
IDs_list = G.edata['ID'].cpu().detach().numpy().tolist()
for i in range(len(edge_mask_list)):
    explainer_result['edge_importance'].append({'ID': IDs_list[i], 'importance': edge_mask_list[i]})
explainer_result['pred_origin'] = pred_origin[G.edata['ID'] == eid].argmax(dim=1).cpu().detach().numpy().tolist()[0]
explainer_result['pred_feature_masked'] = pred_feature_masked[G.edata['ID'] == eid].argmax(dim=1).cpu().detach().numpy().tolist()[0]
explainer_result['pred_edge_masked'] = pred_edge_masked[G.edata['ID'] == eid].argmax(dim=1).cpu().detach().numpy().tolist()[0]
explainer_result['pred_origin_vec'] = F.softmax(pred_origin[G.edata['ID'] == eid].cpu().detach()[0], dim=0).numpy().tolist()
explainer_result['pred_feature_masked_vec'] = F.softmax(pred_feature_masked[G.edata['ID'] == eid].cpu().detach()[0], dim=0).numpy().tolist()
explainer_result['pred_edge_masked_vec'] = F.softmax(pred_edge_masked[G.edata['ID'] == eid].cpu().detach()[0], dim=0).numpy().tolist()
explainer_result
# Out:
# {'feature_importance': [[0.7475952506065369,
#    0.6981897950172424,
#    0.7815020084381104,
#    0.03672857582569122,
#    0.010007871314883232,
#    0.8463085889816284,
#    0.017531868070364,
#    0.07080043852329254,
#    0.07350192964076996,
#    0.2058211863040924,
#    0.3138639032840729,
#    0.48621708154678345,
#    0.1819811463356018,
#    0.24940809607505798,
#    0.33669155836105347,
#    0.11877613514661789,
#    0.48662227392196655,
#    0.8780620694160461,
#    0.04725721850991249,
#    0.012688416056334972,
#    0.015838418155908585,
#    0.019332755357027054,
#    0.01359010674059391,
#    0.032267436385154724,
#    0.011080511845648289,
#    0.026396675035357475,
#    0.011471792124211788,
#    0.08486545830965042,
#    0.08209795504808426,
#    0.017423519864678383]],
#  'edge_importance': [{'ID': 186511, 'importance': 0.9017619490623474},
#   {'ID': 186511, 'importance': 0.7871096134185791},
#   {'ID': 186569, 'importance': 0.7341153025627136},
#   {'ID': 186570, 'importance': 0.7341153025627136},
#   {'ID': 186571, 'importance': 0.7341153025627136},
#   {'ID': 186572, 'importance': 0.7341153025627136},
#   {'ID': 186573, 'importance': 0.7341151833534241},
#   {'ID': 186574, 'importance': 0.7339855432510376},
#   {'ID': 186575, 'importance': 0.7339850068092346},
#   {'ID': 186576, 'importance': 0.7340315580368042},
#   {'ID': 186577, 'importance': 0.7340313196182251},
#   {'ID': 186578, 'importance': 0.7339841723442078},
#   {'ID': 186579, 'importance': 0.7339838147163391},
#   {'ID': 186580, 'importance': 0.7427340745925903},
#   {'ID': 186581, 'importance': 0.7356641888618469},
#   {'ID': 186582, 'importance': 0.7358548641204834},
#   {'ID': 186583, 'importance': 0.7428935170173645},
#   {'ID': 186584, 'importance': 0.7453874349594116},
#   {'ID': 186585, 'importance': 0.8024386167526245},
#   {'ID': 186815, 'importance': 0.09704204648733139},
#   {'ID': 190027, 'importance': 0.7957829833030701},
#   {'ID': 190028, 'importance': 0.7957786917686462},
#   {'ID': 190029, 'importance': 0.7956567406654358},
#   {'ID': 190030, 'importance': 0.7956998348236084},
#   {'ID': 190031, 'importance': 0.7957791686058044},
#   {'ID': 190032, 'importance': 0.7956545948982239},
#   {'ID': 190033, 'importance': 0.7958418130874634},
#   {'ID': 190034, 'importance': 0.7959062457084656},
#   {'ID': 190043, 'importance': 0.7958407998085022},
#   {'ID': 190044, 'importance': 0.7958375215530396},
#   {'ID': 190045, 'importance': 0.7958359718322754},
#   {'ID': 190046, 'importance': 0.7958370447158813},
#   {'ID': 190047, 'importance': 0.795738935470581},
#   {'ID': 190048, 'importance': 0.7958044409751892},
#   {'ID': 190049, 'importance': 0.7957436442375183},
#   {'ID': 190050, 'importance': 0.7957970499992371},
#   {'ID': 190051, 'importance': 0.7958044409751892},
#   {'ID': 190072, 'importance': 0.7957367897033691},
#   {'ID': 190073, 'importance': 0.04374474659562111},
#   {'ID': 190074, 'importance': 0.0437447652220726},
#   {'ID': 190075, 'importance': 0.04418358951807022},
#   {'ID': 190076, 'importance': 0.04420545697212219},
#   {'ID': 190077, 'importance': 0.04420550540089607},
#   {'ID': 190078, 'importance': 0.04431532695889473},
#   {'ID': 190079, 'importance': 0.04433344304561615},
#   {'ID': 190080, 'importance': 0.04433391988277435},
#   {'ID': 190178, 'importance': 0.04444408789277077},
#   {'ID': 190381, 'importance': 0.7957807183265686},
#   {'ID': 190382, 'importance': 0.795705258846283},
#   {'ID': 190383, 'importance': 0.7958418130874634},
#   {'ID': 190386, 'importance': 0.7959057092666626},
#   {'ID': 190387, 'importance': 0.795754075050354},
#   {'ID': 190388, 'importance': 0.7957818508148193},
#   {'ID': 190389, 'importance': 0.7956554293632507},
#   {'ID': 190390, 'importance': 0.7957819700241089},
#   {'ID': 190391, 'importance': 0.795704185962677},
#   {'ID': 190392, 'importance': 0.7958033680915833},
#   {'ID': 190400, 'importance': 0.7959070205688477},
#   {'ID': 190401, 'importance': 0.7958418130874634},
#   {'ID': 190402, 'importance': 0.05650174990296364},
#   {'ID': 190403, 'importance': 0.7959064245223999},
#   {'ID': 190404, 'importance': 0.7958317399024963},
#   {'ID': 190405, 'importance': 0.05666724219918251},
#   {'ID': 190406, 'importance': 0.7957438826560974},
#   {'ID': 190407, 'importance': 0.795738697052002},
#   {'ID': 190408, 'importance': 0.05696461349725723},
#   {'ID': 190415, 'importance': 0.7957978844642639},
#   {'ID': 190416, 'importance': 0.7957313656806946},
#   {'ID': 190417, 'importance': 0.057206086814403534},
#   {'ID': 190418, 'importance': 0.030289294198155403},
#   {'ID': 190419, 'importance': 0.057362865656614304},
#   {'ID': 190420, 'importance': 0.030221104621887207},
#   {'ID': 190519, 'importance': 0.0575089268386364},
#   {'ID': 190520, 'importance': 0.030161282047629356},
#   {'ID': 190600, 'importance': 0.7957780957221985},
#   {'ID': 190601, 'importance': 0.7957791686058044},
#   {'ID': 190602, 'importance': 0.7957026958465576},
#   {'ID': 190603, 'importance': 0.795776903629303},
#   {'ID': 190604, 'importance': 0.7957056760787964},
#   {'ID': 190605, 'importance': 0.795656144618988},
#   {'ID': 190606, 'importance': 0.7957813143730164},
#   {'ID': 190628, 'importance': 0.7956567406654358},
#   {'ID': 190629, 'importance': 0.7958893179893494},
#   {'ID': 190630, 'importance': 0.7959091067314148},
#   {'ID': 190631, 'importance': 0.7958402037620544},
#   {'ID': 190632, 'importance': 0.7957826852798462},
#   {'ID': 190633, 'importance': 0.7956565022468567},
#   {'ID': 190634, 'importance': 0.7958434224128723},
#   {'ID': 190635, 'importance': 0.7957783341407776},
#   {'ID': 190636, 'importance': 0.7956584692001343},
#   {'ID': 190637, 'importance': 0.7959089875221252},
#   {'ID': 190638, 'importance': 0.7958887219429016},
#   {'ID': 190639, 'importance': 0.7958404421806335},
#   {'ID': 190640, 'importance': 0.7958412766456604},
#   {'ID': 190641, 'importance': 0.7959100008010864},
#   {'ID': 190642, 'importance': 0.7955806851387024},
#   {'ID': 190643, 'importance': 0.7957577705383301},
#   {'ID': 190644, 'importance': 0.7957558035850525},
#   {'ID': 190645, 'importance': 0.7957534790039062},
#   {'ID': 190646, 'importance': 0.7958437204360962},
#   {'ID': 190671, 'importance': 0.7958061099052429},
#   {'ID': 190672, 'importance': 0.7956375479698181},
#   {'ID': 190673, 'importance': 0.7958956956863403},
#   {'ID': 190674, 'importance': 0.7957455515861511},
#   {'ID': 190675, 'importance': 0.7958055138587952},
#   {'ID': 190676, 'importance': 0.7958047986030579},
#   {'ID': 190677, 'importance': 0.7955668568611145},
#   {'ID': 190678, 'importance': 0.7957425117492676},
#   {'ID': 190679, 'importance': 0.043177541345357895},
#   {'ID': 190680, 'importance': 0.04316655918955803},
#   {'ID': 190681, 'importance': 0.043189264833927155},
#   {'ID': 190682, 'importance': 0.7957353591918945},
#   {'ID': 190683, 'importance': 0.795570969581604},
#   {'ID': 190684, 'importance': 0.043187215924263},
#   {'ID': 190685, 'importance': 0.04330626502633095},
#   {'ID': 190686, 'importance': 0.04331577569246292},
#   {'ID': 190687, 'importance': 0.0432969331741333},
#   {'ID': 190688, 'importance': 0.04332052916288376},
#   {'ID': 190699, 'importance': 0.04331422597169876},
#   {'ID': 190700, 'importance': 0.04344131797552109},
#   {'ID': 190701, 'importance': 0.043450772762298584},
#   {'ID': 190702, 'importance': 0.043428685516119},
#   {'ID': 190703, 'importance': 0.04345158115029335},
#   {'ID': 190704, 'importance': 0.04344381392002106},
#   {'ID': 190705, 'importance': 0.04359050840139389},
#   {'ID': 190718, 'importance': 0.04369983449578285},
#   {'ID': 190719, 'importance': 0.04416035860776901},
#   {'ID': 190720, 'importance': 0.04428417980670929},
#   {'ID': 191340, 'importance': 0.7867927551269531},
#   {'ID': 191341, 'importance': 0.7867927551269531},
#   {'ID': 191342, 'importance': 0.7867927551269531},
#   {'ID': 191361, 'importance': 0.7867927551269531},
#   {'ID': 191362, 'importance': 0.7867927551269531},
#   {'ID': 191363, 'importance': 0.7867927551269531},
#   {'ID': 191364, 'importance': 0.7867927551269531},
#   {'ID': 191365, 'importance': 0.7867927551269531},
#   {'ID': 191366, 'importance': 0.7867927551269531},
#   {'ID': 191367, 'importance': 0.7867927551269531},
#   {'ID': 191368, 'importance': 0.7867927551269531},
#   {'ID': 191369, 'importance': 0.7867927551269531},
#   {'ID': 191372, 'importance': 0.7957795262336731},
#   {'ID': 191373, 'importance': 0.7956584692001343},
#   {'ID': 191382, 'importance': 0.7958342432975769},
#   {'ID': 191383, 'importance': 0.7958999276161194},
#   {'ID': 191392, 'importance': 0.7957946062088013},
#   {'ID': 191393, 'importance': 0.795772135257721},
#   {'ID': 191394, 'importance': 0.026857301592826843},
#   {'ID': 191418, 'importance': 0.026777662336826324},
#   {'ID': 191419, 'importance': 0.026744259521365166},
#   {'ID': 191877, 'importance': 0.7867927551269531},
#   {'ID': 191878, 'importance': 0.7867927551269531},
#   {'ID': 191879, 'importance': 0.7867927551269531},
#   {'ID': 191956, 'importance': 0.7867927551269531},
#   {'ID': 191957, 'importance': 0.7867927551269531},
#   {'ID': 191974, 'importance': 0.7867927551269531},
#   {'ID': 192064, 'importance': 0.7957780957221985},
#   {'ID': 192065, 'importance': 0.7956540584564209},
#   {'ID': 192080, 'importance': 0.7958359718322754},
#   {'ID': 192081, 'importance': 0.7958324551582336},
#   {'ID': 192082, 'importance': 0.7957386374473572},
#   {'ID': 192096, 'importance': 0.7957317233085632},
#   {'ID': 192097, 'importance': 0.7951223254203796},
#   {'ID': 192098, 'importance': 0.7951204180717468},
#   {'ID': 192116, 'importance': 0.7952365279197693},
#   {'ID': 192228, 'importance': 0.7867927551269531},
#   {'ID': 192229, 'importance': 0.7867927551269531},
#   {'ID': 192230, 'importance': 0.7956462502479553},
#   {'ID': 192231, 'importance': 0.795831024646759},
#   {'ID': 192233, 'importance': 0.7956040501594543},
#   {'ID': 192234, 'importance': 0.7958627939224243},
#   {'ID': 192235, 'importance': 0.7957942485809326},
#   {'ID': 192236, 'importance': 0.7867927551269531},
#   {'ID': 192237, 'importance': 0.7956191897392273},
#   {'ID': 192238, 'importance': 0.7957583665847778},
#   {'ID': 192239, 'importance': 0.7957683801651001},
#   {'ID': 192240, 'importance': 0.7957538366317749},
#   {'ID': 192241, 'importance': 0.7958303093910217},
#   {'ID': 192242, 'importance': 0.7956953644752502},
#   {'ID': 192243, 'importance': 0.7956497073173523},
#   {'ID': 192244, 'importance': 0.7956517934799194},
#   {'ID': 192245, 'importance': 0.7956991195678711},
#   {'ID': 192246, 'importance': 0.7956531047821045},
#   {'ID': 192247, 'importance': 0.7956525087356567},
#   {'ID': 192248, 'importance': 0.795647919178009},
#   {'ID': 192249, 'importance': 0.795654833316803},
#   {'ID': 192250, 'importance': 0.7956559658050537},
#   {'ID': 192251, 'importance': 0.7956545352935791},
#   {'ID': 192252, 'importance': 0.7956565022468567},
#   {'ID': 192253, 'importance': 0.795653223991394},
#   {'ID': 192254, 'importance': 0.7957026958465576},
#   {'ID': 192255, 'importance': 0.7957509756088257},
#   {'ID': 192256, 'importance': 0.7957497835159302},
#   {'ID': 192257, 'importance': 0.795738935470581},
#   {'ID': 192258, 'importance': 0.7957341074943542},
#   {'ID': 192259, 'importance': 0.795734167098999},
#   {'ID': 192260, 'importance': 0.7957324981689453},
#   {'ID': 192261, 'importance': 0.7905091643333435},
#   {'ID': 192262, 'importance': 0.07457464933395386},
#   {'ID': 192263, 'importance': 0.07482843846082687},
#   {'ID': 192264, 'importance': 0.07506520301103592},
#   {'ID': 192267, 'importance': 0.7957751750946045},
#   {'ID': 192268, 'importance': 0.7956435680389404},
#   {'ID': 192269, 'importance': 0.7958031296730042},
#   {'ID': 192270, 'importance': 0.7957914471626282},
#   {'ID': 192271, 'importance': 0.7957420349121094},
#   {'ID': 192272, 'importance': 0.7957515716552734},
#   {'ID': 192273, 'importance': 0.7954420447349548},
#   {'ID': 192274, 'importance': 0.7954434156417847},
#   {'ID': 192275, 'importance': 0.7955683469772339},
#   {'ID': 192276, 'importance': 0.7956372499465942},
#   {'ID': 192277, 'importance': 0.7958331108093262},
#   {'ID': 192278, 'importance': 0.7956069707870483},
#   {'ID': 192279, 'importance': 0.7958632707595825},
#   {'ID': 192280, 'importance': 0.7957940697669983},
#   {'ID': 192281, 'importance': 0.7956723570823669},
#   {'ID': 192282, 'importance': 0.7957540154457092},
#   {'ID': 192283, 'importance': 0.7957656979560852},
#   {'ID': 192284, 'importance': 0.7957515120506287},
#   {'ID': 192285, 'importance': 0.7958307266235352},
#   {'ID': 192286, 'importance': 0.7956480979919434},
#   {'ID': 192287, 'importance': 0.7956497669219971},
#   {'ID': 192288, 'importance': 0.7956496477127075},
#   {'ID': 192289, 'importance': 0.7956514358520508},
#   {'ID': 192290, 'importance': 0.7956542372703552},
#   {'ID': 192291, 'importance': 0.795656144618988},
#   {'ID': 192292, 'importance': 0.7956530451774597},
#   {'ID': 192293, 'importance': 0.7956520915031433},
#   {'ID': 192294, 'importance': 0.7956504821777344},
#   {'ID': 192295, 'importance': 0.7956517338752747},
#   {'ID': 192296, 'importance': 0.7956530451774597},
#   {'ID': 192297, 'importance': 0.7956545352935791},
#   {'ID': 192298, 'importance': 0.7956567406654358},
#   {'ID': 192299, 'importance': 0.795760452747345},
#   {'ID': 192300, 'importance': 0.7957589030265808},
#   {'ID': 192301, 'importance': 0.7957406640052795},
#   {'ID': 192302, 'importance': 0.7867927551269531},
#   {'ID': 192303, 'importance': 0.7867927551269531},
#   {'ID': 192304, 'importance': 0.7957395315170288},
#   {'ID': 192305, 'importance': 0.7957381010055542},
#   {'ID': 192306, 'importance': 0.795738697052002},
#   {'ID': 192307, 'importance': 0.7905164361000061},
#   {'ID': 192308, 'importance': 0.07461264729499817},
#   {'ID': 192309, 'importance': 0.0748404785990715},
#   {'ID': 192310, 'importance': 0.07508336007595062},
#   {'ID': 194130, 'importance': 0.7956972718238831},
#   {'ID': 194131, 'importance': 0.024422919377684593},
#   {'ID': 194132, 'importance': 0.024471241980791092},
#   {'ID': 194133, 'importance': 0.024471640586853027},
#   {'ID': 194177, 'importance': 0.024467501789331436},
#   {'ID': 194178, 'importance': 0.02445492148399353},
#   {'ID': 194179, 'importance': 0.024430766701698303},
#   {'ID': 194180, 'importance': 0.02443055622279644},
#   {'ID': 194181, 'importance': 0.02443934790790081},
#   {'ID': 194182, 'importance': 0.02444000169634819},
#   {'ID': 194183, 'importance': 0.024493586272001266},
#   {'ID': 194184, 'importance': 0.02442479506134987},
#   {'ID': 194185, 'importance': 0.024420613422989845},
#   {'ID': 194186, 'importance': 0.024418484419584274},
#   {'ID': 194187, 'importance': 0.02441505901515484},
#   {'ID': 194188, 'importance': 0.024515045806765556},
#   {'ID': 194189, 'importance': 0.024501556530594826},
#   {'ID': 194190, 'importance': 0.024425707757472992},
#   {'ID': 194191, 'importance': 0.024463778361678123},
#   {'ID': 194192, 'importance': 0.024457592517137527},
#   {'ID': 194193, 'importance': 0.13520026206970215},
#   {'ID': 194194, 'importance': 0.024453649297356606},
#   {'ID': 194195, 'importance': 0.024451855570077896},
#   {'ID': 194196, 'importance': 0.02444961480796337},
#   {'ID': 194197, 'importance': 0.024432891979813576},
#   {'ID': 194230, 'importance': 0.02449260652065277},
#   {'ID': 194231, 'importance': 0.024484461173415184},
#   {'ID': 194232, 'importance': 0.024648256599903107},
#   {'ID': 194233, 'importance': 0.7958194613456726},
#   {'ID': 194496, 'importance': 0.7963309288024902},
#   {'ID': 194497, 'importance': 0.7957205772399902},
#   {'ID': 194617, 'importance': 0.10162054747343063},
#   {'ID': 194618, 'importance': 0.1024368405342102},
#   {'ID': 194619, 'importance': 0.733177125453949},
#   {'ID': 194993, 'importance': 0.7958109378814697},
#   {'ID': 194994, 'importance': 0.795691967010498},
#   {'ID': 194995, 'importance': 0.10156404972076416},
#   {'ID': 195100, 'importance': 0.10258015990257263},
#   {'ID': 195101, 'importance': 0.10208211094141006},
#   {'ID': 195207, 'importance': 0.7957790493965149},
#   {'ID': 195208, 'importance': 0.7956901788711548},
#   {'ID': 195209, 'importance': 0.7957783341407776},
#   {'ID': 195210, 'importance': 0.10173794627189636},
#   {'ID': 195211, 'importance': 0.10197232663631439},
#   {'ID': 195253, 'importance': 0.10174611955881119},
#   {'ID': 195254, 'importance': 0.10198233276605606},
#   {'ID': 195255, 'importance': 0.7331688404083252},
#   {'ID': 195256, 'importance': 0.7331688404083252},
#   {'ID': 195302, 'importance': 0.7957690358161926},
#   {'ID': 195303, 'importance': 0.7957171201705933},
#   {'ID': 195313, 'importance': 0.10122766345739365},
#   {'ID': 195314, 'importance': 0.1014576330780983},
#   {'ID': 195315, 'importance': 0.733177661895752},
#   {'ID': 195333, 'importance': 0.7858636975288391},
#   {'ID': 195334, 'importance': 0.7858490943908691},
#   {'ID': 195335, 'importance': 0.7858636975288391},
#   {'ID': 195336, 'importance': 0.7959210276603699},
#   {'ID': 195337, 'importance': 0.7957916259765625},
#   {'ID': 195369, 'importance': 0.7959349751472473},
#   {'ID': 195370, 'importance': 0.7956950068473816},
#   {'ID': 195371, 'importance': 0.7959339618682861},
#   {'ID': 195440, 'importance': 0.7973193526268005},
#   {'ID': 195441, 'importance': 0.7956662774085999},
#   {'ID': 195442, 'importance': 0.7959020733833313},
#   {'ID': 195443, 'importance': 0.7957817912101746},
#   {'ID': 195444, 'importance': 0.7958378195762634},
#   {'ID': 195530, 'importance': 0.7956414222717285},
#   {'ID': 195531, 'importance': 0.7959567904472351},
#   {'ID': 195532, 'importance': 0.7957823872566223},
#   {'ID': 195533, 'importance': 0.7957777976989746},
#   {'ID': 195553, 'importance': 0.7957831025123596},
#   {'ID': 195554, 'importance': 0.7957713603973389},
#   {'ID': 195555, 'importance': 0.7958404421806335},
#   {'ID': 195556, 'importance': 0.795953094959259},
#   {'ID': 195557, 'importance': 0.7956619262695312},
#   {'ID': 195570, 'importance': 0.7956638932228088},
#   {'ID': 195571, 'importance': 0.7959439754486084},
#   {'ID': 195572, 'importance': 0.7956644296646118},
#   {'ID': 195573, 'importance': 0.7956624627113342},
#   {'ID': 195574, 'importance': 0.7959612011909485},
#   {'ID': 195589, 'importance': 0.7957789897918701},
#   {'ID': 195590, 'importance': 0.7956648468971252},
#   {'ID': 195591, 'importance': 0.10139299184083939},
#   {'ID': 195592, 'importance': 0.7956649661064148},
#   {'ID': 195593, 'importance': 0.102010577917099},
#   {'ID': 195594, 'importance': 0.7959516048431396},
#   {'ID': 195595, 'importance': 0.7956644892692566},
#   {'ID': 195596, 'importance': 0.7331684231758118},
#   {'ID': 195609, 'importance': 0.7956566214561462},
#   {'ID': 195610, 'importance': 0.7957809567451477},
#   {'ID': 195611, 'importance': 0.7956587076187134},
#   {'ID': 195612, 'importance': 0.7956578731536865},
#   {'ID': 195613, 'importance': 0.7957441806793213},
#   {'ID': 195626, 'importance': 0.7867927551269531},
#   {'ID': 195627, 'importance': 0.7867927551269531},
#   {'ID': 195628, 'importance': 0.7867927551269531},
#   {'ID': 195629, 'importance': 0.7956570982933044},
#   {'ID': 195630, 'importance': 0.7956602573394775},
#   {'ID': 195631, 'importance': 0.7957709431648254},
#   {'ID': 195632, 'importance': 0.7956624627113342},
#   {'ID': 195645, 'importance': 0.7957614660263062},
#   {'ID': 195646, 'importance': 0.7957651615142822},
#   {'ID': 195647, 'importance': 0.7957590818405151},
#   {'ID': 195648, 'importance': 0.7957354187965393},
#   {'ID': 195649, 'importance': 0.7957574129104614},
#   {'ID': 195660, 'importance': 0.7957367897033691},
#   {'ID': 195661, 'importance': 0.7957358956336975},
#   {'ID': 195662, 'importance': 0.7963061928749084},
#   {'ID': 195663, 'importance': 0.7957371473312378},
#   {'ID': 195676, 'importance': 0.7905282974243164},
#   {'ID': 195677, 'importance': 0.07461489737033844},
#   {'ID': 195678, 'importance': 0.07484228909015656},
#   {'ID': 195690, 'importance': 0.07508517056703568},
#   {'ID': 195729, 'importance': 0.7957828640937805},
#   {'ID': 195730, 'importance': 0.10180123150348663},
#   {'ID': 195731, 'importance': 0.10202587395906448},
#   {'ID': 195744, 'importance': 0.7867927551269531},
#   {'ID': 195745, 'importance': 0.7867927551269531},
#   {'ID': 195746, 'importance': 0.7867927551269531},
#   {'ID': 195747, 'importance': 0.7331775426864624},
#   {'ID': 195832, 'importance': 0.7957245111465454},
#   {'ID': 195833, 'importance': 0.10178011655807495},
#   {'ID': 195848, 'importance': 0.10201084613800049},
#   {'ID': 195849, 'importance': 0.7331703901290894},
#   {'ID': 195911, 'importance': 0.7957817912101746},
#   {'ID': 195912, 'importance': 0.10180777311325073},
#   {'ID': 195923, 'importance': 0.10203257948160172},
#   {'ID': 195924, 'importance': 0.7331692576408386},
#   {'ID': 195945, 'importance': 0.7867927551269531},
#   {'ID': 195946, 'importance': 0.7867927551269531},
#   {'ID': 195947, 'importance': 0.7867927551269531},
#   {'ID': 196114, 'importance': 0.7973230481147766},
#   {'ID': 196115, 'importance': 0.7907493710517883},
#   {'ID': 196154, 'importance': 0.1610001176595688},
#   {'ID': 196175, 'importance': 0.1609978824853897},
#   {'ID': 196194, 'importance': 0.16099987924098969},
#   {'ID': 196430, 'importance': 0.7867927551269531},
#   {'ID': 196431, 'importance': 0.7867927551269531},
#   {'ID': 196462, 'importance': 0.7867927551269531},
#   {'ID': 196686, 'importance': 0.7957785725593567},
#   {'ID': 196756, 'importance': 0.7973187565803528},
#   {'ID': 196757, 'importance': 0.7957770824432373},
#   {'ID': 196775, 'importance': 0.7959538102149963},
#   {'ID': 196797, 'importance': 0.7959522604942322},
#   {'ID': 196798, 'importance': 0.7973185777664185},
#   {'ID': 196883, 'importance': 0.7959538698196411},
#   {'ID': 196969, 'importance': 0.7957754731178284},
#   {'ID': 196970, 'importance': 0.7957674264907837},
#   {'ID': 196988, 'importance': 0.7957003712654114},
#   {'ID': 196997, 'importance': 0.7957690358161926},
#   {'ID': 196998, 'importance': 0.7963083386421204},
#   {'ID': 197000, 'importance': 0.7957783937454224},
#   {'ID': 197001, 'importance': 0.10178998857736588},
#   {'ID': 197003, 'importance': 0.10201442986726761},
#   {'ID': 197004, 'importance': 0.7331674098968506},
#   {'ID': 197006, 'importance': 0.7957656383514404},
#   {'ID': 197007, 'importance': 0.10174334794282913},
#   {'ID': 197009, 'importance': 0.10200575739145279},
#   {'ID': 197010, 'importance': 0.7331762313842773},
#   {'ID': 197013, 'importance': 0.7957838177680969},
#   {'ID': 197014, 'importance': 0.10136047750711441},
#   {'ID': 197015, 'importance': 0.10159683972597122},
#   {'ID': 197016, 'importance': 0.733174204826355},
#   {'ID': 197018, 'importance': 0.7957835793495178},
#   {'ID': 197019, 'importance': 0.10174737870693207},
#   {'ID': 197021, 'importance': 0.1019735038280487},
#   {'ID': 197022, 'importance': 0.7331687808036804},
#   {'ID': 197025, 'importance': 0.7957822680473328},
#   {'ID': 197026, 'importance': 0.10172739624977112},
#   {'ID': 197027, 'importance': 0.10196313261985779},
#   {'ID': 197028, 'importance': 0.733170747756958},
#   {'ID': 197125, 'importance': 0.7866144180297852},
#   {'ID': 197126, 'importance': 0.7866141200065613},
#   {'ID': 197173, 'importance': 0.7866144180297852},
#   {'ID': 197233, 'importance': 0.7957824468612671},
#   {'ID': 197234, 'importance': 0.0995958149433136},
#   {'ID': 197235, 'importance': 0.7958118915557861},
#   {'ID': 197236, 'importance': 0.1004011332988739},
#   {'ID': 197252, 'importance': 0.09986395388841629},
#   {'ID': 197253, 'importance': 0.7957845330238342},
#   {'ID': 197254, 'importance': 0.10039858520030975},
#   {'ID': 197255, 'importance': 0.10062220692634583},
#   {'ID': 197256, 'importance': 0.10016164183616638},
#   {'ID': 197257, 'importance': 0.10063055157661438},
#   {'ID': 197258, 'importance': 0.7957729697227478},
#   {'ID': 197259, 'importance': 0.10092413425445557},
#   {'ID': 197260, 'importance': 0.10018422454595566},
#   {'ID': 197261, 'importance': 0.10093369334936142},
#   {'ID': 197279, 'importance': 0.10040684789419174},
#   {'ID': 197280, 'importance': 0.7957711219787598},
#   {'ID': 197281, 'importance': 0.10023462027311325},
#   {'ID': 197282, 'importance': 0.10062476992607117},
#   {'ID': 197283, 'importance': 0.7958115339279175},
#   {'ID': 197284, 'importance': 0.10020849853754044},
#   {'ID': 197285, 'importance': 0.7957780361175537},
#   {'ID': 197286, 'importance': 0.10035901516675949},
#   {'ID': 197287, 'importance': 0.7957779169082642},
#   {'ID': 197288, 'importance': 0.10064775496721268},
#   {'ID': 197289, 'importance': 0.10048814117908478},
#   {'ID': 197290, 'importance': 0.7957848310470581},
#   {'ID': 197291, 'importance': 0.10124999284744263},
#   {'ID': 197292, 'importance': 0.10044609010219574},
#   {'ID': 197293, 'importance': 0.10060364753007889},
#   {'ID': 197294, 'importance': 0.10087952762842178},
#   {'ID': 197326, 'importance': 0.7957784533500671},
#   {'ID': 197327, 'importance': 0.10079982876777649},
#   {'ID': 197328, 'importance': 0.10074710100889206},
#   {'ID': 197329, 'importance': 0.10148085653781891},
#   {'ID': 197330, 'importance': 0.7957757711410522},
#   {'ID': 197331, 'importance': 0.10034379363059998},
#   {'ID': 197332, 'importance': 0.10069508850574493},
#   {'ID': 197333, 'importance': 0.1008763536810875},
#   {'ID': 197334, 'importance': 0.10105167329311371},
#   {'ID': 197335, 'importance': 0.7957783937454224},
#   {'ID': 197336, 'importance': 0.1007242202758789},
#   {'ID': 197337, 'importance': 0.10117422789335251},
#   {'ID': 197338, 'importance': 0.10058751702308655},
#   {'ID': 197339, 'importance': 0.1017722636461258},
#   {'ID': 197340, 'importance': 0.10098309814929962},
#   {'ID': 197341, 'importance': 0.10132230073213577},
#   {'ID': 197342, 'importance': 0.10089389234781265},
#   {'ID': 197366, 'importance': 0.7957798838615417},
#   {'ID': 197367, 'importance': 0.10068977624177933},
#   {'ID': 197368, 'importance': 0.10134577751159668},
#   {'ID': 197369, 'importance': 0.1009368896484375},
#   {'ID': 197370, 'importance': 0.795783281326294},
#   {'ID': 197371, 'importance': 0.10071538388729095},
#   {'ID': 197372, 'importance': 0.7957764863967896},
#   {'ID': 197373, 'importance': 0.10054893791675568},
#   {'ID': 197374, 'importance': 0.10116612166166306},
#   {'ID': 197375, 'importance': 0.10094375908374786},
#   {'ID': 197404, 'importance': 0.10117197781801224},
#   {'ID': 197405, 'importance': 0.10121074318885803},
#   {'ID': 197406, 'importance': 0.10148206353187561},
#   {'ID': 197445, 'importance': 0.7958992719650269},
#   {'ID': 197446, 'importance': 0.10124118626117706},
#   {'ID': 197475, 'importance': 0.10148872435092926},
#   {'ID': 197476, 'importance': 0.7957777380943298},
#   {'ID': 197477, 'importance': 0.10125932097434998},
#   {'ID': 197478, 'importance': 0.7957941889762878},
#   {'ID': 197479, 'importance': 0.10119501501321793},
#   {'ID': 197480, 'importance': 0.10176502913236618},
#   {'ID': 197481, 'importance': 0.7957797050476074},
#   {'ID': 197482, 'importance': 0.10079751908779144},
#   {'ID': 197483, 'importance': 0.10151055455207825},
#   {'ID': 197484, 'importance': 0.795770525932312},
#   {'ID': 197485, 'importance': 0.10091301053762436},
#   {'ID': 197486, 'importance': 0.10143014043569565},
#   {'ID': 197487, 'importance': 0.10102641582489014},
#   {'ID': 197488, 'importance': 0.10179436951875687},
#   {'ID': 197489, 'importance': 0.7957794666290283},
#   {'ID': 197490, 'importance': 0.10158108919858932},
#   {'ID': 197564, 'importance': 0.10117407143115997},
#   {'ID': 197565, 'importance': 0.10127081722021103},
#   {'ID': 197566, 'importance': 0.1017475351691246},
#   {'ID': 197567, 'importance': 0.10182977467775345},
#   {'ID': 197568, 'importance': 0.7957780361175537},
#   {'ID': 197569, 'importance': 0.10100918263196945},
#   {'ID': 197570, 'importance': 0.7957758903503418},
#   {'ID': 197571, 'importance': 0.10085983574390411},
#   {'ID': 197572, 'importance': 0.10146069526672363},
#   {'ID': 197573, 'importance': 0.7958092093467712},
#   {'ID': 197574, 'importance': 0.10084710270166397},
#   {'ID': 197575, 'importance': 0.7331682443618774},
#   {'ID': 197576, 'importance': 0.10110043734312057},
#   {'ID': 197577, 'importance': 0.1012486070394516},
#   {'ID': 197578, 'importance': 0.7958129644393921},
#   {'ID': 197579, 'importance': 0.10105064511299133},
#   {'ID': 197638, 'importance': 0.1010829508304596},
#   {'ID': 197639, 'importance': 0.7957704067230225},
#   {'ID': 197640, 'importance': 0.10140732675790787},
#   {'ID': 197641, 'importance': 0.1015440821647644},
#   {'ID': 197642, 'importance': 0.10201768577098846},
#   {'ID': 197643, 'importance': 0.7957795262336731},
#   {'ID': 197644, 'importance': 0.10112600028514862},
#   {'ID': 197645, 'importance': 0.10130754113197327},
#   {'ID': 197646, 'importance': 0.795782744884491},
#   {'ID': 197647, 'importance': 0.10153459757566452},
#   {'ID': 197648, 'importance': 0.1013479009270668},
#   {'ID': 197649, 'importance': 0.10164862126111984},
#   {'ID': 197650, 'importance': 0.1017412319779396},
#   {'ID': 197651, 'importance': 0.10154128074645996},
#   {'ID': 197652, 'importance': 0.1017829030752182},
#   {'ID': 197653, 'importance': 0.7957791686058044},
#   {'ID': 197654, 'importance': 0.10115402936935425},
#   {'ID': 197655, 'importance': 0.10189370810985565},
#   {'ID': 197656, 'importance': 0.7957690954208374},
#   {'ID': 197657, 'importance': 0.10089181363582611},
#   {'ID': 197747, 'importance': 0.10140486806631088},
#   {'ID': 197748, 'importance': 0.1017061322927475},
#   {'ID': 197749, 'importance': 0.7331696152687073},
#   {'ID': 197750, 'importance': 0.10117113590240479},
#   {'ID': 197751, 'importance': 0.10169124603271484},
#   {'ID': 197752, 'importance': 0.10147383064031601},
#   {'ID': 200115, 'importance': 0.7957832217216492},
#   {'ID': 200116, 'importance': 0.10179305821657181},
#   {'ID': 200117, 'importance': 0.10202936828136444},
#   {'ID': 200135, 'importance': 0.7331671118736267},
#   {'ID': 200153, 'importance': 0.7957775592803955},
#   {'ID': 200154, 'importance': 0.10179277509450912},
#   {'ID': 200155, 'importance': 0.10202303528785706},
#   {'ID': 200156, 'importance': 0.7331780195236206},
#   {'ID': 200176, 'importance': 0.7957814931869507},
#   {'ID': 200177, 'importance': 0.10180847346782684},
#   {'ID': 200196, 'importance': 0.10204296559095383},
#   {'ID': 200197, 'importance': 0.7331781983375549},
#   {'ID': 200215, 'importance': 0.7957773208618164},
#   {'ID': 200216, 'importance': 0.10177154839038849},
#   ...],
#  'pred_origin': 8,
#  'pred_feature_masked': 8,
#  'pred_edge_masked': 8,
#  'pred_origin_vec': [0.0048085665330290794,
#   7.969224585790968e-11,
#   0.01609177328646183,
#   0.00055283511755988,
#   0.24081556499004364,
#   9.998456334869843e-06,
#   5.427831979432085e-07,
#   1.8106567267750506e-06,
#   0.7373191714286804,
#   0.0003996258310507983],
#  'pred_feature_masked_vec': [0.010053965263068676,
#   1.0603143252296832e-08,
#   0.035022057592868805,
#   0.007228758651763201,
#   0.36696964502334595,
#   0.0001119395237765275,
#   1.5214963013931992e-06,
#   3.2673739042365924e-05,
#   0.5766546130180359,
#   0.00392485735937953],
#  'pred_edge_masked_vec': [0.01146448589861393,
#   1.9586922306302768e-08,
#   0.01947864145040512,
#   0.001986313611268997,
#   0.2351565659046173,
#   4.299439751775935e-05,
#   1.2578321957334992e-06,
#   1.2407303984218743e-05,
#   0.7285505533218384,
#   0.0033067534677684307]}

# %%
F.softmax(pred_origin[G.edata['ID'] == eid].cpu().detach()[0]).numpy().tolist()
# Out:
# C:\Users\QishuoBai\AppData\Local\Temp\ipykernel_11024\1283397429.py:1: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   F.softmax(pred_origin[G.edata['ID'] == eid].cpu().detach()[0]).numpy().tolist()
# [0.0048085665330290794,
#  7.969224585790968e-11,
#  0.01609177328646183,
#  0.00055283511755988,
#  0.24081556499004364,
#  9.998456334869843e-06,
#  5.427831979432085e-07,
#  1.8106567267750506e-06,
#  0.7373191714286804,
#  0.0003996258310507983]
